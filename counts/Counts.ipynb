# %% [markdown]
# Counts on the dataset of estimated residential parking permit (RPP) parking spots in DC.

# %%
import pandas as pd

# %%
tableau_10 = {
    'blue': '#4E79A7'
    , 'orange': '#F28E2B'
    , 'red': '#E15759'
    , 'cyan': '#76B7B2'
    , 'green': '#59A14F'
    , 'yellow': '#EDC948'
    , 'purple': '#B07AA1'
    , 'pink': '#FF9DA7'
    , 'brown': '#9C755F'
    , 'grey': '#BAB0AC'
    }

# %%
estimated_spots = pd.read_csv('../output/estimated_rpp_spots_anc_census.csv')

# %% [markdown]
# ## Total

# %%
print('Total RPP spots: {:,.0f}'.format(len(estimated_spots)))
# Out:
# Total RPP spots: 155,077

# %% [markdown]
# ## RPP Spots by Ward

# %%
count_by_ward = pd.DataFrame(estimated_spots.groupby('ward').size(), columns=['rpp_spots'])
count_by_ward.style.bar(vmin=0).format('{:,}')
# Out:
# <style  type="text/css" >
# #T_2ec58c00_fbab_11ea_b3c9_acde48001122row0_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 38.5%, transparent 38.5%);
#         }#T_2ec58c00_fbab_11ea_b3c9_acde48001122row1_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 40.0%, transparent 40.0%);
#         }#T_2ec58c00_fbab_11ea_b3c9_acde48001122row2_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }#T_2ec58c00_fbab_11ea_b3c9_acde48001122row3_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 60.2%, transparent 60.2%);
#         }#T_2ec58c00_fbab_11ea_b3c9_acde48001122row4_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 44.7%, transparent 44.7%);
#         }#T_2ec58c00_fbab_11ea_b3c9_acde48001122row5_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 72.5%, transparent 72.5%);
#         }#T_2ec58c00_fbab_11ea_b3c9_acde48001122row6_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 29.5%, transparent 29.5%);
#         }#T_2ec58c00_fbab_11ea_b3c9_acde48001122row7_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 12.8%, transparent 12.8%);
#         }</style><table id="T_2ec58c00_fbab_11ea_b3c9_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rpp_spots</th>    </tr>    <tr>        <th class="index_name level0" >ward</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2ec58c00_fbab_11ea_b3c9_acde48001122level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_2ec58c00_fbab_11ea_b3c9_acde48001122row0_col0" class="data row0 col0" >14,997</td>
#             </tr>
#             <tr>
#                         <th id="T_2ec58c00_fbab_11ea_b3c9_acde48001122level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_2ec58c00_fbab_11ea_b3c9_acde48001122row1_col0" class="data row1 col0" >15,591</td>
#             </tr>
#             <tr>
#                         <th id="T_2ec58c00_fbab_11ea_b3c9_acde48001122level0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_2ec58c00_fbab_11ea_b3c9_acde48001122row2_col0" class="data row2 col0" >38,947</td>
#             </tr>
#             <tr>
#                         <th id="T_2ec58c00_fbab_11ea_b3c9_acde48001122level0_row3" class="row_heading level0 row3" >4</th>
#                         <td id="T_2ec58c00_fbab_11ea_b3c9_acde48001122row3_col0" class="data row3 col0" >23,448</td>
#             </tr>
#             <tr>
#                         <th id="T_2ec58c00_fbab_11ea_b3c9_acde48001122level0_row4" class="row_heading level0 row4" >5</th>
#                         <td id="T_2ec58c00_fbab_11ea_b3c9_acde48001122row4_col0" class="data row4 col0" >17,405</td>
#             </tr>
#             <tr>
#                         <th id="T_2ec58c00_fbab_11ea_b3c9_acde48001122level0_row5" class="row_heading level0 row5" >6</th>
#                         <td id="T_2ec58c00_fbab_11ea_b3c9_acde48001122row5_col0" class="data row5 col0" >28,238</td>
#             </tr>
#             <tr>
#                         <th id="T_2ec58c00_fbab_11ea_b3c9_acde48001122level0_row6" class="row_heading level0 row6" >7</th>
#                         <td id="T_2ec58c00_fbab_11ea_b3c9_acde48001122row6_col0" class="data row6 col0" >11,475</td>
#             </tr>
#             <tr>
#                         <th id="T_2ec58c00_fbab_11ea_b3c9_acde48001122level0_row7" class="row_heading level0 row7" >8</th>
#                         <td id="T_2ec58c00_fbab_11ea_b3c9_acde48001122row7_col0" class="data row7 col0" >4,976</td>
#             </tr>
#     </tbody></table>

# %%
count_by_ward.to_csv('spots_by_ward.csv')

# %% [markdown]
# ## Total Area of Parking
#
# How much area is devoted to on-street residential permit parking?

# %%
parking_spot_length_feet = 21
parking_spot_width_feet = 9

# %%
parking_spot_area_sqft = parking_spot_length_feet * parking_spot_width_feet
rpp_area_sqft = len(estimated_spots) * parking_spot_area_sqft
rpp_area_acres = rpp_area_sqft / 43560
rpp_area_sqmi = rpp_area_sqft / (5280*5280)

# %%
print('Residential Parking Permit area: {:,.0f} square feet'.format(rpp_area_sqft))
print('Residential Parking Permit area: {:,.1f} acres'.format(rpp_area_acres))
print('Residential Parking Permit area: {:,.3f} square miles'.format(rpp_area_sqmi))
# Out:
# Residential Parking Permit area: 29,309,553 square feet
# Residential Parking Permit area: 672.9 acres
# Residential Parking Permit area: 1.051 square miles

# %% [markdown]
# ## Count by Street

# %%
count_by_street = pd.DataFrame(
    estimated_spots.groupby(['street_name', 'street_type', 'quadrant']).size()
    , columns=['rpp_spots']
).reset_index()
count_by_street.to_csv('spots_by_street.csv', index=False)
count_by_street.sample(7)
# Out:
#     street_name street_type quadrant  rpp_spots
# 42         19TH          ST       NW        333
# 26         15TH          ST       NW        537
# 894       WYLIE          ST       NE         42
# 188     ALLISON          ST       NW        398
# 86         33RD          PL       NW         82
# 379     FLORIDA         AVE       NW        524
# 271      CHAPIN          ST       NW         77

# %% [markdown]
# ## Count by ANC

# %%
count_by_anc = pd.DataFrame(estimated_spots.groupby('ANC_ID').size(), columns=['rpp_spots'])
count_by_anc.style.bar(vmin=0, color=tableau_10['blue']).format('{:,}')
# Out:
# <style  type="text/css" >
# #T_2f13c4c4_fbab_11ea_b3c9_acde48001122row0_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#4E79A7 48.2%, transparent 48.2%);
#         }#T_2f13c4c4_fbab_11ea_b3c9_acde48001122row1_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#4E79A7 47.9%, transparent 47.9%);
#         }#T_2f13c4c4_fbab_11ea_b3c9_acde48001122row2_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#4E79A7 32.1%, transparent 32.1%);
#         }#T_2f13c4c4_fbab_11ea_b3c9_acde48001122row3_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#4E79A7 19.9%, transparent 19.9%);
#         }#T_2f13c4c4_fbab_11ea_b3c9_acde48001122row4_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#4E79A7 14.6%, transparent 14.6%);
#         }#T_2f13c4c4_fbab_11ea_b3c9_acde48001122row5_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#4E79A7 32.3%, transparent 32.3%);
#         }#T_2f13c4c4_fbab_11ea_b3c9_acde48001122row6_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#4E79A7 1.7%, transparent 1.7%);
#         }#T_2f13c4c4_fbab_11ea_b3c9_acde48001122row7_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#4E79A7 19.4%, transparent 19.4%);
#         }#T_2f13c4c4_fbab_11ea_b3c9_acde48001122row8_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#4E79A7 58.0%, transparent 58.0%);
#         }#T_2f13c4c4_fbab_11ea_b3c9_acde48001122row9_col0,#T_2f13c4c4_fbab_11ea_b3c9_acde48001122row19_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#4E79A7 25.4%, transparent 25.4%);
#         }#T_2f13c4c4_fbab_11ea_b3c9_acde48001122row10_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#4E79A7 28.1%, transparent 28.1%);
#         }#T_2f13c4c4_fbab_11ea_b3c9_acde48001122row11_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#4E79A7 97.3%, transparent 97.3%);
#         }#T_2f13c4c4_fbab_11ea_b3c9_acde48001122row12_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#4E79A7 79.8%, transparent 79.8%);
#         }#T_2f13c4c4_fbab_11ea_b3c9_acde48001122row13_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#4E79A7 85.5%, transparent 85.5%);
#         }#T_2f13c4c4_fbab_11ea_b3c9_acde48001122row14_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#4E79A7 54.2%, transparent 54.2%);
#         }#T_2f13c4c4_fbab_11ea_b3c9_acde48001122row15_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#4E79A7 39.2%, transparent 39.2%);
#         }#T_2f13c4c4_fbab_11ea_b3c9_acde48001122row16_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#4E79A7 82.2%, transparent 82.2%);
#         }#T_2f13c4c4_fbab_11ea_b3c9_acde48001122row17_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#4E79A7 63.2%, transparent 63.2%);
#         }#T_2f13c4c4_fbab_11ea_b3c9_acde48001122row18_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#4E79A7 59.5%, transparent 59.5%);
#         }#T_2f13c4c4_fbab_11ea_b3c9_acde48001122row20_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#4E79A7 28.4%, transparent 28.4%);
#         }#T_2f13c4c4_fbab_11ea_b3c9_acde48001122row21_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#4E79A7 37.2%, transparent 37.2%);
#         }#T_2f13c4c4_fbab_11ea_b3c9_acde48001122row22_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#4E79A7 23.7%, transparent 23.7%);
#         }#T_2f13c4c4_fbab_11ea_b3c9_acde48001122row23_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#4E79A7 21.5%, transparent 21.5%);
#         }#T_2f13c4c4_fbab_11ea_b3c9_acde48001122row24_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#4E79A7 60.6%, transparent 60.6%);
#         }#T_2f13c4c4_fbab_11ea_b3c9_acde48001122row25_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#4E79A7 68.3%, transparent 68.3%);
#         }#T_2f13c4c4_fbab_11ea_b3c9_acde48001122row26_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#4E79A7 100.0%, transparent 100.0%);
#         }#T_2f13c4c4_fbab_11ea_b3c9_acde48001122row27_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#4E79A7 44.2%, transparent 44.2%);
#         }#T_2f13c4c4_fbab_11ea_b3c9_acde48001122row28_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#4E79A7 31.0%, transparent 31.0%);
#         }#T_2f13c4c4_fbab_11ea_b3c9_acde48001122row29_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#4E79A7 29.0%, transparent 29.0%);
#         }#T_2f13c4c4_fbab_11ea_b3c9_acde48001122row30_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#4E79A7 23.6%, transparent 23.6%);
#         }#T_2f13c4c4_fbab_11ea_b3c9_acde48001122row31_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#4E79A7 16.5%, transparent 16.5%);
#         }#T_2f13c4c4_fbab_11ea_b3c9_acde48001122row32_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#4E79A7 50.1%, transparent 50.1%);
#         }#T_2f13c4c4_fbab_11ea_b3c9_acde48001122row33_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#4E79A7 12.5%, transparent 12.5%);
#         }#T_2f13c4c4_fbab_11ea_b3c9_acde48001122row34_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#4E79A7 14.0%, transparent 14.0%);
#         }#T_2f13c4c4_fbab_11ea_b3c9_acde48001122row35_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#4E79A7 19.1%, transparent 19.1%);
#         }#T_2f13c4c4_fbab_11ea_b3c9_acde48001122row36_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#4E79A7 6.8%, transparent 6.8%);
#         }#T_2f13c4c4_fbab_11ea_b3c9_acde48001122row37_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#4E79A7 10.8%, transparent 10.8%);
#         }#T_2f13c4c4_fbab_11ea_b3c9_acde48001122row38_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#4E79A7 5.1%, transparent 5.1%);
#         }#T_2f13c4c4_fbab_11ea_b3c9_acde48001122row39_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#4E79A7 6.7%, transparent 6.7%);
#         }</style><table id="T_2f13c4c4_fbab_11ea_b3c9_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rpp_spots</th>    </tr>    <tr>        <th class="index_name level0" >ANC_ID</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>

# %%
count_by_anc.to_csv('spots_by_anc.csv')

# %% [markdown]
# ## Census Block

# %%
# Convert to a nullable int format
estimated_spots['GEOID10'] = estimated_spots['GEOID10'].round(0).astype('Int64')

# %%
count_by_cb = pd.DataFrame(estimated_spots.groupby('GEOID10').size(), columns=['rpp_spots'])
count_by_cb.to_csv('spots_by_census_block.csv')
